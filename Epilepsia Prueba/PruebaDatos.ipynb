# %%
import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import clear_output
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks

f = 0;
i = 1;
minValue = 49500;
maxValue = 51000;

with open("FA0010VB.txt") as infile:

    for line in infile:
        if(f==2):
            data = line.strip().split()
            print(data[18].replace('-0.','0.'))
            df = pd.DataFrame([float(data[18].replace('-0.','0.'))], columns =['Value'])
            print(df)
        elif(f>minValue):
            #print(f);
            #clear_output()
            data = line.strip().split()
            df.loc[i]=[float(data[18].replace('-0.','0.'))]
            i += 1
        if(f>maxValue):
            break
        f += 1
        #print(f);
        #clear_output()
df.head()
x =df['Value'];
peaks, _ = find_peaks(x, distance=220)
#peaks, _ = find_peaks(x, prominence=1, width=10)
print(peaks)
plt.plot(figsize=(25,8))
plt.plot(df)
plt.plot(peaks, x[peaks], "x")
# Out:
# 0.00
#    Value
# 0    0.0
# [ 155  380  814 1255 1489]
